# %%
import pandas as pd
import numpy as np

# Load dataset
df = pd.read_csv("Student_Performance_Dataset.csv")

# Display dataset
display(df)
# Out:
#      Student_ID  Age  Gender  Class  Study_Hours_Per_Day  \
# 0         S0001   15    Male     12                  1.0
# 1         S0002   19  Female      9                  1.6
# 2         S0003   14  Female     12                  3.6
# 3         S0004   18  Female      9                  5.5
# 4         S0005   14    Male     10                  5.0
# ...         ...  ...     ...    ...                  ...
# 4995      S4996   17    Male     11                  4.0
# 4996      S4997   19    Male     10                  5.6
# 4997      S4998   16  Female      9                  2.3
# 4998      S4999   15    Male     11                  2.9
# 4999      S5000   19  Female     10                  2.0
#
#       Attendance_Percentage Parental_Education Internet_Access  \
# 0                        65       Postgraduate              No
# 1                        58           Graduate              No
# 2                        64        High School             Yes
# ...

# %%
print("Pandas version:", pd.__version__)
print("Built on top of NumPy version:", np.__version__)
# Out:
# Pandas version: 3.0.3
# Built on top of NumPy version: 2.5.1

# %%
s = pd.Series([80, 75, 90, 85], index=["A", "B", "C", "D"], name="Marks")

print(s)
print("\nType:", type(s))
print("Value at label 'B':", s["B"])
# Out:
# A    80
# B    75
# C    90
# D    85
# Name: Marks, dtype: int64
#
# Type: <class 'pandas.Series'>
# Value at label 'B': 75

# %%
print("Type:", type(df))
print("Columns:", list(df.columns))
print("Index:", df.index.tolist())

display(df)
# Out:
# Type: <class 'pandas.DataFrame'>
# Columns: ['Student_ID', 'Age', 'Gender', 'Class', 'Study_Hours_Per_Day', 'Attendance_Percentage', 'Parental_Education', 'Internet_Access', 'Extracurricular_Activities', 'Math_Score', 'Science_Score', 'English_Score', 'Previous_Year_Score', 'Final_Percentage', 'Performance_Level', 'Pass_Fail']
# ...

# %%
df.to_csv("students.csv", index=False)
df_from_csv = pd.read_csv("students.csv")

df.to_json("students.json", orient="records")
df_from_json = pd.read_json("students.json")

display(df_from_csv.tail())
# Out:
#      Student_ID  Age  Gender  Class  Study_Hours_Per_Day  \
# 4995      S4996   17    Male     11                  4.0
# 4996      S4997   19    Male     10                  5.6
# 4997      S4998   16  Female      9                  2.3
# 4998      S4999   15    Male     11                  2.9
# 4999      S5000   19  Female     10                  2.0
#
#       Attendance_Percentage Parental_Education Internet_Access  \
# 4995                     50           Graduate              No
# 4996                     90        High School             Yes
# 4997                     61           Graduate              No
# 4998                     82           Graduate              No
# 4999                     97       Postgraduate              No
#
#      Extracurricular_Activities  Math_Score  Science_Score  English_Score  \
# 4995                         No          64             60             70
# 4996                         No          44             59             43
# ...

# %%
print("First 3 rows:")
display(df.head(3))

print("Last 3 rows:")
display(df.tail(3))

print("Info:")
df.info()

print("Describe:")
display(df.describe())

print("Shape:", df.shape)
# Out:
# First 3 rows:
#   Student_ID  Age  Gender  Class  Study_Hours_Per_Day  Attendance_Percentage  \
# 0      S0001   15    Male     12                  1.0                     65
# 1      S0002   19  Female      9                  1.6                     58
# 2      S0003   14  Female     12                  3.6                     64
#
#   Parental_Education Internet_Access Extracurricular_Activities  Math_Score  \
# 0       Postgraduate              No                         No          40
# 1           Graduate              No                        Yes          80
# 2        High School             Yes                        Yes          83
#
#    Science_Score  English_Score  Previous_Year_Score  Final_Percentage  \
# 0             39             72                   81             50.33
# 1             44             35                   47             53.00
# 2             73             59                   58             71.67
#
#   Performance_Level Pass_Fail
# ...

# %%
print("loc example:")
display(df.loc[0:2, ["Student_ID", "Gender", "Final_Percentage"]])

print("iloc example:")
display(df.iloc[0:3, 0:4])

print("Students who Passed:")
display(df[df["Pass_Fail"] == "Pass"])
# Out:
# loc example:
#   Student_ID  Gender  Final_Percentage
# 0      S0001    Male             50.33
# 1      S0002  Female             53.00
# 2      S0003  Female             71.67
# iloc example:
#   Student_ID  Age  Gender  Class
# 0      S0001   15    Male     12
# 1      S0002   19  Female      9
# 2      S0003   14  Female     12
# Students who Passed:
#      Student_ID  Age  Gender  Class  Study_Hours_Per_Day  \
# 0         S0001   15    Male     12                  1.0
# 1         S0002   19  Female      9                  1.6
# 2         S0003   14  Female     12                  3.6
# 3         S0004   18  Female      9                  5.5
# 5         S0006   19    Male     12                  5.2
# ...         ...  ...     ...    ...                  ...
# 4994      S4995   15    Male      9                  4.0
# 4995      S4996   17    Male     11                  4.0
# 4997      S4998   16  Female      9                  2.3
# ...

# %%
print("Average Final Percentage by Gender:")
display(df.groupby("Gender")["Final_Percentage"].mean())
# Out:
# Average Final Percentage by Gender:
# Gender
# Female    67.419890
# Male      67.537924
# Name: Final_Percentage, dtype: float64

# %%
print("Average Math Score by Performance Level:")
display(df.groupby("Performance_Level")["Math_Score"].mean())
# Out:
# Average Math Score by Performance Level:
# Performance_Level
# Average      59.705792
# Excellent    84.994941
# Good         72.869466
# Poor         46.147170
# Name: Math_Score, dtype: float64

# %%
display(df.groupby("Gender").agg(
    Avg_Final=("Final_Percentage", "mean"),
    Avg_Math=("Math_Score", "mean"),
    Student_Count=("Student_ID", "count")
))
# Out:
#         Avg_Final   Avg_Math  Student_Count
# Gender
# Female  67.419890  67.784567           2553
# Male    67.537924  67.723743           2447

# %%
pivot = pd.pivot_table(
    df,
    values="Final_Percentage",
    index="Gender",
    columns="Performance_Level",
    aggfunc="mean",
    fill_value=0
)

display(pivot)
# Out:
# Performance_Level    Average  Excellent       Good       Poor
# Gender
# Female             59.228601  85.480334  72.677213  45.813507
# Male               58.990406  85.684422  72.646077  45.537557

# %%
print("Missing values:")
display(df.isnull().sum())

print("Rows containing missing values:")
display(df[df.isnull().any(axis=1)])

print("Drop missing values:")
display(df.dropna())
# Out:
# Missing values:
# Student_ID                    0
# Age                           0
# Gender                        0
# Class                         0
# Study_Hours_Per_Day           0
# Attendance_Percentage         0
# Parental_Education            0
# Internet_Access               0
# Extracurricular_Activities    0
# Math_Score                    0
# Science_Score                 0
# English_Score                 0
# Previous_Year_Score           0
# Final_Percentage              0
# Performance_Level             0
# Pass_Fail                     0
# dtype: int64
# Rows containing missing values:
# Empty DataFrame
# Columns: [Student_ID, Age, Gender, Class, Study_Hours_Per_Day, Attendance_Percentage, Parental_Education, Internet_Access, Extracurricular_Activities, Math_Score, Science_Score, English_Score, Previous_Year_Score, Final_Percentage, Performance_Level, Pass_Fail]
# Index: []
# Drop missing values:
#      Student_ID  Age  Gender  Class  Study_Hours_Per_Day  \
# ...

# %%
df_filled = df.copy()

df_filled["Study_Hours_Per_Day"] = df_filled["Study_Hours_Per_Day"].fillna(
    df_filled["Study_Hours_Per_Day"].mean()
)

display(df_filled.head())
# Out:
#   Student_ID  Age  Gender  Class  Study_Hours_Per_Day  Attendance_Percentage  \
# 0      S0001   15    Male     12                  1.0                     65
# 1      S0002   19  Female      9                  1.6                     58
# 2      S0003   14  Female     12                  3.6                     64
# 3      S0004   18  Female      9                  5.5                     68
# 4      S0005   14    Male     10                  5.0                     80
#
#   Parental_Education Internet_Access Extracurricular_Activities  Math_Score  \
# 0       Postgraduate              No                         No          40
# 1           Graduate              No                        Yes          80
# 2        High School             Yes                        Yes          83
# 3       Postgraduate             Yes                         No          68
# 4        High School             Yes                         No          41
#
# ...

# %%
df_t = df_filled.copy()

# Total Marks
df_t["Total_Marks"] = df_t.apply(
    lambda row: row["Math_Score"] + row["Science_Score"] + row["English_Score"],
    axis=1
)

# Map Gender
gender_code = {
    "Male": "M",
    "Female": "F"
}

df_t["Gender_Code"] = df_t["Gender"].map(gender_code)

# Change datatype
df_t["Age"] = df_t["Age"].astype(int)

# Rename column
df_t = df_t.rename(columns={"Final_Percentage": "Final_Result"})

# Sort by Final Result
df_t = df_t.sort_values(by="Final_Result", ascending=False)

display(df_t)
# Out:
#      Student_ID  Age  Gender  Class  Study_Hours_Per_Day  \
# 21        S0022   15    Male     12                  2.8
# 3636      S3637   15  Female      9                  3.8
# 3748      S3749   17    Male     11                  0.5
# 2211      S2212   19    Male     11                  1.8
# 1599      S1600   14    Male      9                  5.0
# ...         ...  ...     ...    ...                  ...
# 1684      S1685   14  Female     10                  1.0
# 1686      S1687   15  Female     11                  5.4
# 2157      S2158   16  Female      9                  5.2
# 3190      S3191   15    Male      9                  5.0
# 2718      S2719   16    Male     11                  5.1
#
#       Attendance_Percentage Parental_Education Internet_Access  \
# 21                       83       Postgraduate              No
# 3636                     90        High School              No
# 3748                     60           Graduate              No
# ...

# %%
extra_info = pd.DataFrame({
    "Student_ID": ["S0001","S0002","S0003","S0004","S0005"],
    "City": ["Pune","Mumbai","Nashik","Nagpur","Aurangabad"],
    "Scholarship": ["Yes","No","Yes","No","Yes"]
})

# %%
merged_df = pd.merge(df, extra_info, on="Student_ID", how="left")

print("Merge Result:")
display(merged_df.head())
# Out:
# Merge Result:
#   Student_ID  Age  Gender  Class  Study_Hours_Per_Day  Attendance_Percentage  \
# 0      S0001   15    Male     12                  1.0                     65
# 1      S0002   19  Female      9                  1.6                     58
# 2      S0003   14  Female     12                  3.6                     64
# 3      S0004   18  Female      9                  5.5                     68
# 4      S0005   14    Male     10                  5.0                     80
#
#   Parental_Education Internet_Access Extracurricular_Activities  Math_Score  \
# 0       Postgraduate              No                         No          40
# 1           Graduate              No                        Yes          80
# 2        High School             Yes                        Yes          83
# 3       Postgraduate             Yes                         No          68
# 4        High School             Yes                         No          41
#
# ...

# %%
joined_df = df.set_index("Student_ID").join(
    extra_info.set_index("Student_ID"),
    how="left"
)

print("Join Result:")
display(joined_df.head())
# Out:
# Join Result:
#             Age  Gender  Class  Study_Hours_Per_Day  Attendance_Percentage  \
# Student_ID
# S0001        15    Male     12                  1.0                     65
# S0002        19  Female      9                  1.6                     58
# S0003        14  Female     12                  3.6                     64
# S0004        18  Female      9                  5.5                     68
# S0005        14    Male     10                  5.0                     80
#
#            Parental_Education Internet_Access Extracurricular_Activities  \
# Student_ID
# S0001            Postgraduate              No                         No
# S0002                Graduate              No                        Yes
# S0003             High School             Yes                        Yes
# S0004            Postgraduate             Yes                         No
# S0005             High School             Yes                         No
#
# ...

# %%
batch1 = df.iloc[:50]
batch2 = df.iloc[50:]

concatenated_df = pd.concat([batch1, batch2], ignore_index=True)

print("Concat Result:")
display(concatenated_df)
# Out:
# Concat Result:
#      Student_ID  Age  Gender  Class  Study_Hours_Per_Day  \
# 0         S0001   15    Male     12                  1.0
# 1         S0002   19  Female      9                  1.6
# 2         S0003   14  Female     12                  3.6
# 3         S0004   18  Female      9                  5.5
# 4         S0005   14    Male     10                  5.0
# ...         ...  ...     ...    ...                  ...
# 4995      S4996   17    Male     11                  4.0
# 4996      S4997   19    Male     10                  5.6
# 4997      S4998   16  Female      9                  2.3
# 4998      S4999   15    Male     11                  2.9
# 4999      S5000   19  Female     10                  2.0
#
#       Attendance_Percentage Parental_Education Internet_Access  \
# 0                        65       Postgraduate              No
# 1                        58           Graduate              No
# 2                        64        High School             Yes
# ...
